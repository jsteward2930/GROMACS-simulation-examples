# %%
import sys
sys.path.append('/content/drive/MyDrive/gromacs-on-colab/polyply_1.0/polyply_env/bin')

# %%
import os
os.environ['PATH'] += ":/content/drive/MyDrive/gromacs-on-colab/polyply_1.0/polyply_env/bin"

# %%
# !mkdir example_genome

# %%
# !pip install /content/drive/MyDrive/gromacs-on-colab/polyply_1.0
# Out:
# Processing /content/drive/MyDrive/gromacs-on-colab/polyply_1.0
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# ...
#   Using cached pbr-6.0.0-py2.py3-none-any.whl (107 kB)
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.0/3.0 MB 17.0 MB/s eta 0:00:00
# ...
#   Created wheel for polyply: filename=polyply-1.6.2.dev19-py2.py3-none-any.whl size=723350 sha256=480bad657f7c2ad89a9bc32291ddcd2ff980243bcfaef5d85fbccffc11b6cb99
#   Stored in directory: /tmp/pip-ephem-wheel-cache-dj_ze3uc/wheels/1a/80/d2/2db6a8d627182222ae2ec4ff5d0961fe037b94dfd253d122a9
# Successfully built polyply
# ...

# %%
# !chmod +x /content/drive/MyDrive/gromacs-on-colab/polyply_1.0/polyply_env/bin/polyply

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import os
os.chdir("/content/drive/My Drive/gromacs-on-colab/polyply_1.0/polyply_regression_tests/examples/porcine_genome")

# %%
# !pwd
# Out:
# /content/drive/My Drive/gromacs-on-colab/polyply_1.0/polyply_regression_tests/examples/porcine_genome

# %%
import os
os.environ['PATH'] += ":/content/drive/MyDrive/gromacs-on-colab/gromacs-2023.2/build/bin"

# %%
# %cd example_genome
# Out:
# /content/drive/My Drive/gromacs-on-colab/polyply_1.0/polyply_regression_tests/examples/porcine_genome/example_genome

# %%
# !ls
# Out:
# csDNA.itp  start.gro  system.top

# %%
INPUT_DIR = "/content/drive/MyDrive/gromacs-on-colab/polyply_1.0/polyply_regression_tests/examples/porcine_genome/input"

# %%
# !chmod +x /content/drive/MyDrive/gromacs-on-colab/gromacs-2023.2/build/bin/gmx

# %%
# !gmx grompp -f {INPUT_DIR}/min.mdp -c start.gro -p system.top -o min.tpr -r start.gro
# Out:
#                       :-) GROMACS - gmx grompp, 2023.2 (-:
#
# Executable:   /content/drive/MyDrive/gromacs-on-colab/gromacs-2023.2/build/bin/gmx
# Data prefix:  /content/drive/MyDrive/gromacs-on-colab/gromacs-2023.2 (source tree)
# Working dir:  /content/drive/MyDrive/gromacs-on-colab/polyply_1.0/polyply_regression_tests/examples/porcine_genome/example_genome
# Command line:
#   gmx grompp -f /content/drive/MyDrive/gromacs-on-colab/polyply_1.0/polyply_regression_tests/examples/porcine_genome/input/min.mdp -c start.gro -p system.top -o min.tpr -r start.gro
#
# Ignoring obsolete mdp entry 'gb-algorithm'
# Ignoring obsolete mdp entry 'nstgbradii'
# Ignoring obsolete mdp entry 'rgbradii'
# Ignoring obsolete mdp entry 'gb-epsilon-solvent'
# Ignoring obsolete mdp entry 'gb-saltconc'
# Ignoring obsolete mdp entry 'gb-obc-alpha'
# Ignoring obsolete mdp entry 'gb-obc-beta'
# Ignoring obsolete mdp entry 'gb-obc-gamma'
# Ignoring obsolete mdp entry 'gb-dielectric-offset'
# ...

# %%
# !gmx mdrun -v -deffnm min -s min.tpr -nt 1
# Out:
#                       :-) GROMACS - gmx mdrun, 2023.2 (-:
#
# Executable:   /content/drive/MyDrive/gromacs-on-colab/gromacs-2023.2/build/bin/gmx
# Data prefix:  /content/drive/MyDrive/gromacs-on-colab/gromacs-2023.2 (source tree)
# Working dir:  /content/drive/MyDrive/gromacs-on-colab/polyply_1.0/polyply_regression_tests/examples/porcine_genome/example_genome
# Command line:
#   gmx mdrun -v -deffnm min -s min.tpr -nt 1
#
#
# Back Off! I just backed up min.log to ./#min.log.1#
# Compiled SIMD is AVX2_256, but CPU also supports AVX_512 (see log).
# Reading file min.tpr, VERSION 2023.2 (single precision)
# Using 1 MPI thread
# Using 1 OpenMP thread
#
#
# NOTE: Thread affinity was not set.
#
# Steepest Descents:
#    Tolerance (Fmax)   =  1.00000e+01
#    Number of steps    =         5000
#
# WARNING: Listed nonbonded interaction between particles 216144 and 216119
# at distance 6.720 which is larger than the table limit 2.050 nm.
#
# ...

# %%
# !gmx solvate -cs spc216.gro -cp min.gro -o solvated.gro -p system.top
# Out:
#                      :-) GROMACS - gmx solvate, 2023.2 (-:
#
# Executable:   /content/drive/MyDrive/gromacs-on-colab/gromacs-2023.2/build/bin/gmx
# Data prefix:  /content/drive/MyDrive/gromacs-on-colab/gromacs-2023.2 (source tree)
# Working dir:  /content/drive/MyDrive/gromacs-on-colab/polyply_1.0/polyply_regression_tests/examples/porcine_genome/example_genome
# Command line:
#   gmx solvate -cs spc216.gro -cp min.gro -o solvated.gro -p system.top
#
# Reading solute configuration
# Reading solvent configuration
#
# Initialising inter-atomic distances...
#
# WARNING: Masses and atomic (Van der Waals) radii will be guessed
#          based on residue and atom names, since they could not be
#          definitively assigned from the information in your input
#          files. These guessed numbers might deviate from the mass
#          and radius of the atom type. Please check the output
#          files if necessary. Note, that this functionality may
# ...

# %%
# !gmx grompp -f {INPUT_DIR}/min.mdp -c solvated.gro -p system.top -o min_sol.tpr -r solvated.gro
# Out:
#                       :-) GROMACS - gmx grompp, 2023.2 (-:
#
# Executable:   /content/drive/MyDrive/gromacs-on-colab/gromacs-2023.2/build/bin/gmx
# Data prefix:  /content/drive/MyDrive/gromacs-on-colab/gromacs-2023.2 (source tree)
# Working dir:  /content/drive/MyDrive/gromacs-on-colab/polyply_1.0/polyply_regression_tests/examples/porcine_genome/example_genome
# Command line:
#   gmx grompp -f /content/drive/MyDrive/gromacs-on-colab/polyply_1.0/polyply_regression_tests/examples/porcine_genome/input/min.mdp -c solvated.gro -p system.top -o min_sol.tpr -r solvated.gro
#
# Ignoring obsolete mdp entry 'gb-algorithm'
# Ignoring obsolete mdp entry 'nstgbradii'
# Ignoring obsolete mdp entry 'rgbradii'
# Ignoring obsolete mdp entry 'gb-epsilon-solvent'
# Ignoring obsolete mdp entry 'gb-saltconc'
# Ignoring obsolete mdp entry 'gb-obc-alpha'
# Ignoring obsolete mdp entry 'gb-obc-beta'
# Ignoring obsolete mdp entry 'gb-obc-gamma'
# Ignoring obsolete mdp entry 'gb-dielectric-offset'
# ...

# %%
# !gmx mdrun -v -deffnm min_sol -s min_sol.tpr -nt 1
# Out:
#                       :-) GROMACS - gmx mdrun, 2023.2 (-:
#
# Executable:   /content/drive/MyDrive/gromacs-on-colab/gromacs-2023.2/build/bin/gmx
# Data prefix:  /content/drive/MyDrive/gromacs-on-colab/gromacs-2023.2 (source tree)
# Working dir:  /content/drive/MyDrive/gromacs-on-colab/polyply_1.0/polyply_regression_tests/examples/porcine_genome/example_genome
# Command line:
#   gmx mdrun -v -deffnm min_sol -s min_sol.tpr -nt 1
#
#
# Back Off! I just backed up min_sol.log to ./#min_sol.log.1#
# Compiled SIMD is AVX2_256, but CPU also supports AVX_512 (see log).
# Reading file min_sol.tpr, VERSION 2023.2 (single precision)
# Using 1 MPI thread
# Using 1 OpenMP thread
#
#
# NOTE: Thread affinity was not set.
#
# Back Off! I just backed up min_sol.trr to ./#min_sol.trr.1#
#
# Back Off! I just backed up min_sol.edr to ./#min_sol.edr.1#
#
# Steepest Descents:
#    Tolerance (Fmax)   =  1.00000e+03
#    Number of steps    =         5000
# ...

# %%
# !gmx grompp -f {INPUT_DIR}/eq1.mdp -c min_sol.gro -p system.top -o eq1.tpr -r solvated.gro -maxwarn 2
# Out:
#                       :-) GROMACS - gmx grompp, 2023.2 (-:
#
# Executable:   /content/drive/MyDrive/gromacs-on-colab/gromacs-2023.2/build/bin/gmx
# Data prefix:  /content/drive/MyDrive/gromacs-on-colab/gromacs-2023.2 (source tree)
# Working dir:  /content/drive/MyDrive/gromacs-on-colab/polyply_1.0/polyply_regression_tests/examples/porcine_genome/example_genome
# Command line:
#   gmx grompp -f /content/drive/MyDrive/gromacs-on-colab/polyply_1.0/polyply_regression_tests/examples/porcine_genome/input/eq1.mdp -c min_sol.gro -p system.top -o eq1.tpr -r solvated.gro -maxwarn 2
#
# Ignoring obsolete mdp entry 'ns-type'
#
# WARNING 1 [file /content/drive/MyDrive/gromacs-on-colab/polyply_1.0/polyply_regression_tests/examples/porcine_genome/input/eq1.mdp]:
#   You are generating velocities so I am assuming you are equilibrating a
#   system. You are using Parrinello-Rahman pressure coupling, but this can
#   be unstable for equilibration. If your system crashes, try equilibrating
# ...

# %%
# !gmx mdrun -v -s eq1.tpr -deffnm eq1
# Out:
#                       :-) GROMACS - gmx mdrun, 2023.2 (-:
#
# Executable:   /content/drive/MyDrive/gromacs-on-colab/gromacs-2023.2/build/bin/gmx
# Data prefix:  /content/drive/MyDrive/gromacs-on-colab/gromacs-2023.2 (source tree)
# Working dir:  /content/drive/MyDrive/gromacs-on-colab/polyply_1.0/polyply_regression_tests/examples/porcine_genome/example_genome
# Command line:
#   gmx mdrun -v -s eq1.tpr -deffnm eq1
#
#
# Back Off! I just backed up eq1.log to ./#eq1.log.3#
# Compiled SIMD is AVX2_256, but CPU also supports AVX_512 (see log).
# Reading file eq1.tpr, VERSION 2023.2 (single precision)
# Changing nstlist from 20 to 100, rlist from 1 to 1
#
# Using 1 MPI thread
# Using 12 OpenMP threads
#
#
# Back Off! I just backed up eq1.xtc to ./#eq1.xtc.3#
#
# Back Off! I just backed up eq1.edr to ./#eq1.edr.3#
# starting mdrun 'Protein in #water in water'
# 5000 steps,      0.5 ps.
# step 4900, remaining wall clock time:    23 s
# Writing final coordinates.
# ...

# %%
# !gmx grompp -f {INPUT_DIR}/eq2.mdp -c eq1.gro -p system.top -o eq2.tpr -r solvated.gro -maxwarn 2
# Out:
#                       :-) GROMACS - gmx grompp, 2023.2 (-:
#
# Executable:   /content/drive/MyDrive/gromacs-on-colab/gromacs-2023.2/build/bin/gmx
# Data prefix:  /content/drive/MyDrive/gromacs-on-colab/gromacs-2023.2 (source tree)
# Working dir:  /content/drive/MyDrive/gromacs-on-colab/polyply_1.0/polyply_regression_tests/examples/porcine_genome/example_genome
# Command line:
#   gmx grompp -f /content/drive/MyDrive/gromacs-on-colab/polyply_1.0/polyply_regression_tests/examples/porcine_genome/input/eq2.mdp -c eq1.gro -p system.top -o eq2.tpr -r solvated.gro -maxwarn 2
#
# Ignoring obsolete mdp entry 'ns-type'
#
# NOTE 1 [file /content/drive/MyDrive/gromacs-on-colab/polyply_1.0/polyply_regression_tests/examples/porcine_genome/input/eq2.mdp]:
#   Setting tcoupl from 'V-rescale' to 'no'. sd handles temperature coupling
#   implicitly. See the documentation for more information on which
#   parameters affect temperature for sd.
#
#
# ...

# %%
# !gmx mdrun -v -s eq2.tpr -deffnm eq2
# Out:
#                       :-) GROMACS - gmx mdrun, 2023.2 (-:
#
# Executable:   /content/drive/MyDrive/gromacs-on-colab/gromacs-2023.2/build/bin/gmx
# Data prefix:  /content/drive/MyDrive/gromacs-on-colab/gromacs-2023.2 (source tree)
# Working dir:  /content/drive/MyDrive/gromacs-on-colab/polyply_1.0/polyply_regression_tests/examples/porcine_genome/example_genome
# Command line:
#   gmx mdrun -v -s eq2.tpr -deffnm eq2
#
# Compiled SIMD is AVX2_256, but CPU also supports AVX_512 (see log).
# Reading file eq2.tpr, VERSION 2023.2 (single precision)
# Changing nstlist from 20 to 100, rlist from 1 to 1.091
#
# Using 1 MPI thread
# Using 12 OpenMP threads
#
# starting mdrun 'Protein in #water in water'
# 5000 steps,      5.0 ps.
# step 4900, remaining wall clock time:    26 s
# Writing final coordinates.
# step 5000, remaining wall clock time:     0 s
#                Core t (s)   Wall t (s)        (%)
#        Time:    15688.316     1307.362     1200.0
# ...

# %%
# !gmx grompp -f {INPUT_DIR}/eq3.mdp -c eq2.gro -p system.top -o eq3.tpr -r solvated.gro -maxwarn 2
# Out:
#                       :-) GROMACS - gmx grompp, 2023.2 (-:
#
# Executable:   /content/drive/MyDrive/gromacs-on-colab/gromacs-2023.2/build/bin/gmx
# Data prefix:  /content/drive/MyDrive/gromacs-on-colab/gromacs-2023.2 (source tree)
# Working dir:  /content/drive/MyDrive/gromacs-on-colab/polyply_1.0/polyply_regression_tests/examples/porcine_genome/example_genome
# Command line:
#   gmx grompp -f /content/drive/MyDrive/gromacs-on-colab/polyply_1.0/polyply_regression_tests/examples/porcine_genome/input/eq3.mdp -c eq2.gro -p system.top -o eq3.tpr -r solvated.gro -maxwarn 2
#
# Ignoring obsolete mdp entry 'ns-type'
#
# NOTE 1 [file /content/drive/MyDrive/gromacs-on-colab/polyply_1.0/polyply_regression_tests/examples/porcine_genome/input/eq3.mdp]:
#   Setting tcoupl from 'V-rescale' to 'no'. sd handles temperature coupling
#   implicitly. See the documentation for more information on which
#   parameters affect temperature for sd.
#
#
# ...

# %%
# !gmx mdrun -v -s eq3.tpr -deffnm eq3
# Out:
#                       :-) GROMACS - gmx mdrun, 2023.2 (-:
#
# Executable:   /content/drive/MyDrive/gromacs-on-colab/gromacs-2023.2/build/bin/gmx
# Data prefix:  /content/drive/MyDrive/gromacs-on-colab/gromacs-2023.2 (source tree)
# Working dir:  /content/drive/MyDrive/gromacs-on-colab/polyply_1.0/polyply_regression_tests/examples/porcine_genome/example_genome
# Command line:
#   gmx mdrun -v -s eq3.tpr -deffnm eq3
#
# Compiled SIMD is AVX2_256, but CPU also supports AVX_512 (see log).
# Reading file eq3.tpr, VERSION 2023.2 (single precision)
# Changing nstlist from 20 to 50, rlist from 1.022 to 1.097
#
# Using 1 MPI thread
# Using 12 OpenMP threads
#
# starting mdrun 'Protein in #water in water'
# 5000 steps,     10.0 ps.
# step 4900, remaining wall clock time:    26 s
# Writing final coordinates.
# step 5000, remaining wall clock time:     0 s
#                Core t (s)   Wall t (s)        (%)
#        Time:    15945.194     1328.769     1200.0
# ...
